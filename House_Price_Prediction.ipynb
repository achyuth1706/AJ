# %%
import pandas as pd
import numpy as np
#pd.set_option('max_columns', None)
#pd.set_option('max_rows', None)
from sklearn.neighbors import KNeighborsRegressor

# %%
train = pd.read_csv("C:/Users/achyuth.v/Downloads/hpp/train.csv")
test = pd.read_csv("C:/Users/achyuth.v/Downloads/hpp/test.csv")
ss = pd.read_csv("C:/Users/achyuth.v/Downloads/hpp/sample_submission.csv")

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %%
ss.shape
# Out:
# (1459, 2)

# %%
#Cleaning
#Feature Engineering
#FeatureTransforations
#encoding
#Scaling
#targetTransformation

# %%
#ModelSelection
#Hyperparameter optimisation
#Ensembling
#FeatureSelection

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

cateforical_features = [i for i in train.columns if train[i].dtypes=='O']

for i in cateforical_features:
    df_cf = train.copy()
    df_cf.groupby(i)['SalePrice'].median().plot.bar()
    plt.xlabel(i)
    plt.ylabel('SalePrice')
    plt.title(i)
    plt.show()

# %%
correlation_train=train[train.dtypes[train.dtypes != 'object'].index].corr()
sns.set(font_scale=2)
plt.figure(figsize = (50,35))
ax = sns.heatmap(correlation_train, annot=True,annot_kws={"size": 25},fmt='.1f',cmap='PiYG', linewidths=.5)

# %%
train.loc[:, train.isna().sum() > 0].isna().sum()
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
#We have missing values in the train dataset

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
test.loc[:, test.isna().sum() > 0].isna().sum()
# Out:
# MSZoning           4
# LotFrontage      227
# Alley           1352
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        16
# MasVnrArea        15
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinSF1         1
# BsmtFinType2      42
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageYrBlt       78
# GarageFinish      78
# GarageCars         1
# GarageArea         1
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# SaleType           1
# dtype: int64

# %%
test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %%
test.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
test.loc[:,test.isna().sum() > 0].columns
# Out:
# Index(['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea',
#        'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType'],
#       dtype='object')

# %% [markdown]
# # **Combining Train and test sets**

# %%
target = train['SalePrice']
test_id = test['Id']

train_1 = train.drop(['Id', 'SalePrice'],axis = 1)
test_1 = test.drop('Id', axis = 1)

# %%
df = pd.concat([train_1, test_1], axis = 0)

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1454         160       RM         21.0     1936   Pave   NaN      Reg
# 1455         160       RM         21.0     1894   Pave   NaN      Reg
# 1456          20       RL        160.0    20000   Pave   NaN      Reg
# 1457          85       RL         62.0    10441   Pave   NaN      Reg
# 1458          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# ...

# %%
target
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
min(test_id)
# Out:
# 1461

# %% [markdown]
# ##Cleaning

# %%
df.select_dtypes(np.number)
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
# ...

# %%
df1 = df.copy()

# %%
df1['MSSubClass'] = df1['MSSubClass'].astype(str)

# %%
df1.select_dtypes(np.number).columns
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
  df1.loc[:, df1.isna().sum()>0].select_dtypes('object').columns
# Out:
# Index(['MSZoning', 'Alley', 'Utilities', 'Exterior1st', 'Exterior2nd',
#        'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Electrical', 'KitchenQual', 'Functional',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PoolQC', 'Fence', 'MiscFeature', 'SaleType'],
#       dtype='object')

# %%
#filling values missing
# where the empty values are not NA
for column in ['MSZoning','Utilities','Exterior1st','Exterior2nd','MasVnrType',
    'Electrical','KitchenQual','Functional','SaleType']:
  df1[column] = df1[column].fillna(df1[column].mode()[0])

#where empty values are NA
for column in ['Alley','BsmtQual','BsmtExposure','BsmtCond',
    'BsmtFinType1','BsmtFinType2','FireplaceQu','GarageType',
    'GarageFinish','GarageQual','GarageCond','PoolQC','Fence',
    'MiscFeature']:
  df1[column] = df1[column].fillna('None')

# %%
df1.select_dtypes(np.number).isna().sum().sum()
# Out:
# 678

# %%
df2 = df1.copy()

# %%
#number type missing values
df2.select_dtypes(np.number).isna().sum()
# Out:
# LotFrontage      486
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea        23
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       2
# BsmtHalfBath       2
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt      159
# GarageCars         1
# GarageArea         1
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
df_m = df2.loc[:,df2.isna().sum()>0].select_dtypes(np.number)

# %%
df_m.isna().sum()
# Out:
# LotFrontage     486
# MasVnrArea       23
# BsmtFinSF1        1
# BsmtFinSF2        1
# BsmtUnfSF         1
# TotalBsmtSF       1
# BsmtFullBath      2
# BsmtHalfBath      2
# GarageYrBlt     159
# GarageCars        1
# GarageArea        1
# dtype: int64

# %%
df_m.loc[:,df_m.isna().sum()<3].columns
# Out:
# Index(['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'GarageCars', 'GarageArea'],
#       dtype='object')

# %%
df3=df2.copy()

# %%
df3.select_dtypes(np.number).isna().sum()
# Out:
# LotFrontage      486
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea        23
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       2
# BsmtHalfBath       2
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt      159
# GarageCars         1
# GarageArea         1
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
for i in df_m.loc[:,df_m.isna().sum()>0].columns:
  df3[i] = df3[i].fillna(df3[i].median())

# %%
df3.isna().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 79, dtype: int64

# %%
df3.select_dtypes(np.number).isna().sum()
# Out:
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# dtype: int64

# %%
df_kn = df2.copy()

# %%
def knn_imputing(df, na_column):
  df = df.copy()
  num_df= df.select_dtypes(np.number)
  non_na_columns = num_df.loc[:, num_df.isna().sum() == 0].columns

  y_train = num_df.loc[num_df[na_column].isna() == False, na_column]
  X_train = num_df.loc[num_df[na_column].isna() == False, non_na_columns]
  X_test = num_df.loc[num_df[na_column].isna() == True, non_na_columns]

  knn = KNeighborsRegressor()
  knn.fit(X_train, y_train)

  y_pred = knn.predict(X_test)

  df.loc[df[na_column].isna() == True, na_column] = y_pred

  return df

# %%
na_df_kn = df_kn.loc[:,df_kn.isna().sum()>0].select_dtypes(np.number)

# %%
na_df_kn.columns
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt',
#        'GarageCars', 'GarageArea'],
#       dtype='object')

# %%
for i in ['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
       'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt',
       'GarageCars', 'GarageArea'
]:
  df_kn = knn_imputing(df_kn, i)

# %%
df_kn.isna().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 79, dtype: int64

# %% [markdown]
# ##Feature Transformaion

# %%
import scipy.stats

# %%
scipy.stats.skew(df_kn.select_dtypes(np.number))
# Out:
# array([ 1.34075114, 12.8224314 ,  0.19711045,  0.57031205, -0.59980555,
#        -0.45102038,  2.60368152,  1.42551624,  4.14611071,  0.91932181,
#         1.16280584,  1.46960442,  0.86167475, 12.088761  ,  1.26935769,
#         0.62437257,  3.93159384,  0.16760573,  0.69456649,  0.32632435,
#         4.30225437,  0.75836691,  0.7334946 , -0.34632694, -0.21859252,
#         0.24089573,  1.84243281,  2.53511373,  4.00389122, 11.37606468,
#         3.9466937 , 16.89832792, 21.94719481,  0.19588394,  0.13239881])

# %%
df_skew = pd.DataFrame(df_kn.select_dtypes(np.number).columns, columns = ['Features'])
df_skew['Skewness'] = df_skew['Features'].apply(lambda a: scipy.stats.skew(df_kn[a]))
df_skew['Absolute_Skew'] = df_skew['Skewness'].apply(abs)
df_skew['skewed'] = df_skew['Absolute_Skew'].apply(lambda x: True if x>=0.5 else False)

# %%
df_skew
# Out:
#          Features   Skewness  Absolute_Skew  skewed
# 0     LotFrontage   1.340751       1.340751    True
# 1         LotArea  12.822431      12.822431    True
# 2     OverallQual   0.197110       0.197110   False
# 3     OverallCond   0.570312       0.570312    True
# 4       YearBuilt  -0.599806       0.599806    True
# 5    YearRemodAdd  -0.451020       0.451020   False
# 6      MasVnrArea   2.603682       2.603682    True
# 7      BsmtFinSF1   1.425516       1.425516    True
# 8      BsmtFinSF2   4.146111       4.146111    True
# 9       BsmtUnfSF   0.919322       0.919322    True
# 10    TotalBsmtSF   1.162806       1.162806    True
# 11       1stFlrSF   1.469604       1.469604    True
# 12       2ndFlrSF   0.861675       0.861675    True
# 13   LowQualFinSF  12.088761      12.088761    True
# 14      GrLivArea   1.269358       1.269358    True
# 15   BsmtFullBath   0.624373       0.624373    True
# 16   BsmtHalfBath   3.931594       3.931594    True
# ...

# %%
df_kn[df_skew.query("skewed == True")['Features'].values].describe()
# Out:
#        LotFrontage        LotArea  OverallCond    YearBuilt   MasVnrArea  \
# count  2919.000000    2919.000000  2919.000000  2919.000000  2919.000000
# mean     70.154916   10168.114080     5.564577  1971.312778   102.189654
# std      22.697641    7886.996359     1.113131    30.291442   178.934095
# min      21.000000    1300.000000     1.000000  1872.000000     0.000000
# 25%      60.000000    7478.000000     5.000000  1953.500000     0.000000
# 50%      70.000000    9453.000000     5.000000  1973.000000     0.000000
# 75%      80.100000   11570.000000     6.000000  2001.000000   164.000000
# max     313.000000  215245.000000     9.000000  2010.000000  1600.000000
#
#         BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF  ...  \
# count  2919.000000  2919.000000  2919.000000  2919.000000  2919.000000  ...
# mean    441.332580    49.576841   560.797670  1051.679822  1159.581706  ...
# std     455.559081   169.176867   439.470508   440.722380   392.362079  ...
# ...

# %%
# min values are hitting zero we cant do log transforms, if we need to use Lo transforms we should use log(1+x))

for i in df_skew.query("skewed == True")['Features'].values:
  df_kn[i] = np.log1p(df_kn[i])

# %%
df_skew = pd.DataFrame(df_kn.select_dtypes(np.number).columns, columns = ['Features'])
df_skew['Skewness'] = df_skew['Features'].apply(lambda a: scipy.stats.skew(df_kn[a]))
df_skew['Absolute_Skew'] = df_skew['Skewness'].apply(abs)
df_skew['skewed'] = df_skew['Absolute_Skew'].apply(lambda x: True if x>=0.5 else False)
df_skew
# Out:
#          Features   Skewness  Absolute_Skew  skewed
# 0     LotFrontage   1.340751       1.340751    True
# 1         LotArea  12.822431      12.822431    True
# 2     OverallQual   0.197110       0.197110   False
# 3     OverallCond   0.570312       0.570312    True
# 4       YearBuilt  -0.599806       0.599806    True
# 5    YearRemodAdd  -0.451020       0.451020   False
# 6      MasVnrArea   2.603682       2.603682    True
# 7      BsmtFinSF1   1.425516       1.425516    True
# 8      BsmtFinSF2   4.146111       4.146111    True
# 9       BsmtUnfSF   0.919322       0.919322    True
# 10    TotalBsmtSF   1.162806       1.162806    True
# 11       1stFlrSF   1.469604       1.469604    True
# 12       2ndFlrSF   0.861675       0.861675    True
# 13   LowQualFinSF  12.088761      12.088761    True
# 14      GrLivArea   1.269358       1.269358    True
# 15   BsmtFullBath   0.624373       0.624373    True
# 16   BsmtHalfBath   3.931594       3.931594    True
# ...

# %%
df_kn['MoSold'].unique()
# Out:
# array([ 2,  5,  9, 12, 10,  8, 11,  4,  1,  7,  3,  6], dtype=int64)

# %%
np.mean(-np.cos(0.5236 * df_kn['MoSold']))
# Out:
# 0.34286598537322777

# %%
df_kn['MoSold'] = (-np.cos(0.5236 * df_kn['MoSold']))

# %%
df_t = df_kn.copy()

# %%
df_t
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0            60       RL         65.0     8450   Pave  None      Reg
# 1            20       RL         80.0     9600   Pave  None      Reg
# 2            60       RL         68.0    11250   Pave  None      IR1
# 3            70       RL         60.0     9550   Pave  None      IR1
# 4            60       RL         84.0    14260   Pave  None      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 1454        160       RM         21.0     1936   Pave  None      Reg
# 1455        160       RM         21.0     1894   Pave  None      Reg
# 1456         20       RL        160.0    20000   Pave  None      Reg
# 1457         85       RL         62.0    10441   Pave  None      Reg
# 1458         60       RL         74.0     9627   Pave  None      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# ...

# %% [markdown]
# ##Encode Categories

# %%
df_kn['MSSubClass'] = df_kn['MSSubClass'].astype(str)

# %%
df_dum = pd.get_dummies(df_kn)

# %%
df_dum
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0            65.0     8450            7            5       2003          2003
# 1            80.0     9600            6            8       1976          1976
# 2            68.0    11250            7            5       2001          2002
# 3            60.0     9550            7            5       1915          1970
# 4            84.0    14260            8            5       2000          2000
# ...           ...      ...          ...          ...        ...           ...
# 1454         21.0     1936            4            7       1970          1970
# 1455         21.0     1894            4            5       1970          1970
# 1456        160.0    20000            5            7       1960          1996
# 1457         62.0    10441            5            5       1992          1992
# 1458         74.0     9627            7            5       1993          1994
#
# ...

# %% [markdown]
# ##Scaling

# %%
 df_scale = df_dum.copy()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(df_scale)

df_scale1 = pd.DataFrame(scaler.transform(df_scale), index=df_scale.index, columns = df_scale.columns)

# %%
df_scale1
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       -0.227151 -0.217879     0.646183    -0.507284   1.046258
# 1        0.433824 -0.072044    -0.063185     2.188279   0.154764
# 2       -0.094956  0.137197     0.646183    -0.507284   0.980221
# 3       -0.447476 -0.078385     0.646183    -0.507284  -1.859351
# 4        0.610084  0.518903     1.355551    -0.507284   0.947203
# ...           ...       ...          ...          ...        ...
# 1454    -2.166011 -1.043937    -1.481920     1.289758  -0.043346
# 1455    -2.166011 -1.049263    -1.481920    -0.507284  -0.043346
# 1456     3.959023  1.246808    -0.772552     1.289758  -0.373528
# 1457    -0.359346  0.034605    -0.772552    -0.507284   0.683057
# 1458     0.169434 -0.068620     0.646183    -0.507284   0.716075
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  \
# 0         0.896833    0.524363    0.581072   -0.293098  -0.934916  ...
# ...

# %%
df_kn
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0            60       RL         65.0     8450   Pave  None      Reg
# 1            20       RL         80.0     9600   Pave  None      Reg
# 2            60       RL         68.0    11250   Pave  None      IR1
# 3            70       RL         60.0     9550   Pave  None      IR1
# 4            60       RL         84.0    14260   Pave  None      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 1454        160       RM         21.0     1936   Pave  None      Reg
# 1455        160       RM         21.0     1894   Pave  None      Reg
# 1456         20       RL        160.0    20000   Pave  None      Reg
# 1457         85       RL         62.0    10441   Pave  None      Reg
# 1458         60       RL         74.0     9627   Pave  None      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# ...

# %% [markdown]
# # check point

# %%
dk = df_kn.copy()

# %%
for f in cateforical_features:
    #labels_ordered=dk.groupby([f])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i, k in enumerate(dk,0)}
    dk[f]=dk[f].map(labels_ordered)

# %%
df_kn
# Out:
#      MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0            60       NaN     4.189655  9.042040     NaN    NaN       NaN
# 1            20       NaN     4.394449  9.169623     NaN    NaN       NaN
# 2            60       NaN     4.234107  9.328212     NaN    NaN       NaN
# 3            70       NaN     4.110874  9.164401     NaN    NaN       NaN
# 4            60       NaN     4.442651  9.565284     NaN    NaN       NaN
# ...         ...       ...          ...       ...     ...    ...       ...
# 1454        160       NaN     3.091042  7.568896     NaN    NaN       NaN
# 1455        160       NaN     3.091042  7.546974     NaN    NaN       NaN
# 1456         20       NaN     5.081404  9.903538     NaN    NaN       NaN
# 1457         85       NaN     4.143135  9.253591     NaN    NaN       NaN
# 1458         60       NaN     4.317488  9.172431     NaN    NaN       NaN
#
#       LandContour  Utilities  LotConfig  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
df_scale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Columns: 317 entries, LotFrontage to SaleCondition_Partial
# dtypes: float64(30), int64(5), uint8(282)
# memory usage: 1.6 MB

# %%
x1_train = df_kn.iloc[0:1460, :]
y1_train = train['SalePrice']

# %%
x1_dum_train = df_scale

# %%
import seaborn as sns

# %%
plt.figure(figsize = (20, 10))

sns.displot(target, kde = True)
plt.title("no log Transform")
# Out:
# Text(0.5, 1.0, 'no log Transform')

# %%
plt.figure(figsize = (20, 10))

sns.displot(np.log(target), kde = True)
plt.title("log Transform")
# Out:
# Text(0.5, 1.0, 'log Transform')

# %% [markdown]
# # check point 2

# %%
x1_train = df_kn.iloc[0:1460, :]
y1_train = np.log(target)

# %%
y1_train
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
#           ...
# 1455    12.072541
# 1456    12.254863
# 1457    12.493130
# 1458    11.864462
# 1459    11.901583
# Name: SalePrice, Length: 1460, dtype: float64

# %%
x1_train.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
x1_train = df_scale1.iloc[0:1460, :]
y1_train = np.log(target)

# %%
feature_sel_model = SelectFromModel(Lasso(alpha=0.005, random_state=12)) 
feature_sel_model.fit(x1_train, y1_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=12))

# %%
feature_sel_model.get_support()
# Out:
# array([False,  True,  True,  True,  True,  True, False,  True, False,
#        False,  True,  True, False, False,  True,  True, False,  True,
#         True, False,  True, False,  True, False,  True,  True,  True,
#         True, False, False,  True, False, False,  True, False, False,
#        False,  True, False, False, False,  True, False, False, False,
#        False, False, False, False, False,  True,  True,  True, False,
#        False,  True,  True, False, False, False, False, False, False,
#        False, False,  True, False, False, False,  True, False, False,
#         True,  True, False, False, False, False, False, False, False,
#        False,  True,  True, False,  True,  True, False, False,  True,
#         True, False, False, False,  True,  True, False, False, False,
#        False,  True,  True, False, False,  True, False,  True, False,
#        False,  True, False, False, False, False, False, False, False,
# ...

# %%
selected_feat = x1_train.columns[(feature_sel_model.get_support())]

# let's print some stats
print('total features: {}'.format((x1_train.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
# Out:
# total features: 317
# selected features: 89

# %%
df_kn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   object
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          2919 non-null   object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
# ...

# %%
categorical_features = [i for i in df_kn.columns if train[i].dtypes=='O']

# %%
t = []
for i in df_kn['MSZoning'].unique():
    df_kn['MSZoning'] = df_kn['MSZoning'].map()

# %%
t
# Out:
# ['RL', 'RM', 'C (all)', 'FV', 'RH']

# %%
selected_feat
# Out:
# Index(['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'BsmtFullBath',
#        'FullBath', 'HalfBath', 'KitchenAbvGr', 'Fireplaces', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'ScreenPorch', 'MoSold',
#        'MSSubClass_160', 'MSSubClass_30', 'MSSubClass_90', 'MSZoning_C (all)',
#        'MSZoning_FV', 'MSZoning_RM', 'Street_Grvl', 'LandContour_Bnk',
#        'Utilities_AllPub', 'LotConfig_CulDSac', 'LotConfig_FR2',
#        'Neighborhood_BrkSide', 'Neighborhood_ClearCr', 'Neighborhood_Crawfor',
#        'Neighborhood_Edwards', 'Neighborhood_MeadowV', 'Neighborhood_Mitchel',
#        'Neighborhood_NoRidge', 'Neighborhood_NridgHt', 'Neighborhood_Somerst',
#        'Neighborhood_StoneBr', 'Condition1_Artery', 'Condition1_Norm',
#        'Condition1_RRAe', 'Condition2_PosN', 'BldgType_1Fam',
#        'BldgType_Duplex', 'RoofMatl_ClyTile', 'RoofMatl_WdShngl',
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
x1_train = x1_train[selected_feat]

# %%
x1_train
# Out:
#        LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF1  \
# 0    -0.103719     0.646183    -0.435439   1.040634      0.896833    0.783229
# 1     0.146544    -0.063185     1.906370   0.161526     -0.395604    0.892444
# 2     0.457629     0.646183    -0.435439   0.975922      0.848965    0.658154
# 3     0.136301     0.646183    -0.435439  -1.869638     -0.682812    0.386923
# 4     0.922662     1.355551    -0.435439   0.943542      0.753229    0.758108
# ...        ...          ...          ...        ...           ...         ...
# 1455 -0.231508    -0.063185    -0.435439   0.911146      0.753229   -1.418196
# 1456  0.767440    -0.063185     0.454875   0.227056      0.178812    0.820898
# 1457  0.029092     0.646183     2.514892  -0.996100      1.040437    0.467619
# 1458  0.170303    -0.772552     0.454875  -0.696444      0.561757   -0.105594
# 1459  0.214215    -0.772552     0.454875  -0.200076     -0.922153    0.837450
#
# ...

# %%
model = LinearRegression()
model.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
model.score(x1_train,y1_train)
# Out:
# 0.9392107848162534

# %%
model2 = DecisionTreeRegressor()
model2.fit(x1_train,y1_train)
# Out:
# DecisionTreeRegressor()

# %%
model2.score(x1_train, y1_train)
# Out:
# 1.0
